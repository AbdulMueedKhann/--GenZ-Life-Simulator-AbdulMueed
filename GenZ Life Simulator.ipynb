# %% [markdown]
# Name: Abdul Mueed
# Enrollment:01-136242-002
# Assignment #1 – GenZ Life Simulator
# Unique Feature: Meditation & Self-Care Mode 🧘

# %%
# 🧑‍💻 Abdul Mueed Khan | Enrollment: (Your ID) | Assignment #1: GenZ Life Simulator

# --- Profile Setup ---
def GreetUser():
    print("Hey bestie! Welcome to the GenZ Life Simulator 💅")
    name = input("What's your name? ")
    age = int(input("How old are you? "))
    user = {"name": name, "age": age}
    print(f"Ayy {user['name']} 👋! You're {user['age']} years young and ready to vibe 😎")
    return user

# --- Chatbot Responses ---
responses = {                   # Updated for Better Clarity
    "hi": "Hey bestie! 💅",
    "how are you": "I'm vibing, wbu? 😎",
    "bye": "Aww, see you soon 💖",
    "whats up": "nm just chillin 😌",
    "lol": "😂😂"
}

def GetResponse(user_input):
    user_input = user_input.lower()
    if user_input in responses:
        return responses[user_input]
    else:
        return "Hmm… idk what to say 😶"

def EndChat():
    print("Aww okay bestie, talk soon 💖")

# --- Game Stats ---
stats = {"energy": 100, "points": 0, "mood": "Chill 😌"}

def ShowStatus():
    print(f"\n📊 STATUS: Energy = {stats['energy']}, Points = {stats['points']}, Mood = {stats['mood']}")

def UpdateStats(activity):
    if activity == "study":
        stats["energy"] -= 20
        stats["points"] += 10
        stats["mood"] = "Focused 😎"
    elif activity == "eat":
        stats["energy"] += 15
        stats["mood"] = "Satisfied 😋"
    elif activity == "play":
        stats["energy"] -= 10
        stats["points"] += 5
        stats["mood"] = "Excited 🤪"
    elif activity == "sleep":
        stats["energy"] = 100
        stats["mood"] = "Rested 😴"
    elif activity == "meditate":  # this is my unique feature lol
        stats["energy"] += 10
        stats["mood"] = "Calm 🧘"
        print("You took a break from chaos and meditated 🧘‍♂️✨ Inner peace +10 energy!")
    else:
        print("Invalid choice, bestie 😭")

    ShowStatus()

def EndGame():
    print("\n🛑 Game Over!")
    print(f"Final Stats ➤ Energy: {stats['energy']}, Points: {stats['points']}, Mood: {stats['mood']}")
    print("Thx for playing with your AI bestie 💖")

# --- Game Menu ---
def PlayGame():
    print("\n✨ Welcome to GenZ Life Simulator ✨")
    while True:
        print("\nWhat do you wanna do today?")
        print("1. Study 📚\n2. Eat 🍔\n3. Play Games 🎮\n4. Sleep 😴\n5. Meditate 🧘\n6. Quit 🚪")

        choice = input("Choose an activity: ").lower()

        if choice in ["study", "eat", "play", "sleep", "meditate"]:
            UpdateStats(choice)
        elif choice == "quit":
            EndGame()
            break
        else:
            print("Invalid input 😵 Try again!")

# --- Chatbot Loop ---
def ChatBot():
    user = GreetUser()

    while True:
        msg = input("\nYou: ").lower()

        if msg in ["play", "game"]:
            choice = input("Ooo want to play GenZ Life Simulator with me? (yes/no) 😏 ").lower()
            if choice == "yes":
                PlayGame()
            else:
                print("Aight bestie, we can keep chatting 💬")
        elif msg == "bye":
            EndChat()
            break
        else:
            print("AI Bestie:", GetResponse(msg))

# --- Run the Chatbot ---
ChatBot()
# Out:
# Hey bestie! Welcome to the GenZ Life Simulator 💅
# What's your name? mueed
# How old are you? 18
# Ayy mueed 👋! You're 18 years young and ready to vibe 😎
#
# You: play
# Ooo want to play GenZ Life Simulator with me? (yes/no) 😏 yes
#
# ✨ Welcome to GenZ Life Simulator ✨
#
# What do you wanna do today?
# 1. Study 📚
# 2. Eat 🍔
# 3. Play Games 🎮
# 4. Sleep 😴
# 5. Meditate 🧘
# 6. Quit 🚪
# Choose an activity: study
#
# 📊 STATUS: Energy = 80, Points = 10, Mood = Focused 😎
#
# What do you wanna do today?
# 1. Study 📚
# 2. Eat 🍔
# 3. Play Games 🎮
# 4. Sleep 😴
# 5. Meditate 🧘
# 6. Quit 🚪
# Choose an activity: eat
#
# 📊 STATUS: Energy = 95, Points = 10, Mood = Satisfied 😋
#
# What do you wanna do today?
# 1. Study 📚
# 2. Eat 🍔
# 3. Play Games 🎮
# 4. Sleep 😴
# 5. Meditate 🧘
# 6. Quit 🚪
# Choose an activity: play
#
# 📊 STATUS: Energy = 85, Points = 15, Mood = Excited 🤪
#
# What do you wanna do today?
# 1. Study 📚
# 2. Eat 🍔
# 3. Play Games 🎮
# 4. Sleep 😴
# 5. Meditate 🧘
# 6. Quit 🚪
# ...
